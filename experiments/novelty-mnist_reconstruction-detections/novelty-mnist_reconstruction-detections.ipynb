# %% [markdown]
# ## Caution: important experiment, please do not adjust
#
# The contents within this file are for running a publication-quality experiment and producing the associated figures and results. As such, it is finely tuned for specific high-quality graphics using the `primary.mplstyle` file. Please do not adjust. If you need to replicate results on your local system, please create a new notebook and copy contents from here.

# %%
import sys
sys.path.append('../..')  # Expose top level program access

import time
import pickle
import logging
import torch
import numpy as np
import pandas as pd
import pytorch_lightning as pl
import matplotlib.pyplot as plt

from functools import reduce
from pathlib import Path

from modules.cae_base_module import CAEBaseModule
from modules.vae_base_module import VAEBaseModule
from modules.aae_base_module import AAEBaseModule
from modules.pca_base_module import PCABaseModule
from models import supported_models
from datasets import supported_datamodules
from utils import tools, metrics, supported_preprocessing_transforms

logging.getLogger("matplotlib").setLevel(logging.WARNING)  # Suppress verbose font warnings from matplotlib

# %%
# Import configurations and paths to logged models
root = Path.cwd().parents[1]
log_path = root / 'logs' / 'NoveltyMNISTDataModule'
paths_to_archived_models = list(Path(log_path).glob('**/archive_v*'))

print('Found archived models:\n------')
print('\n'.join([f'{p.parent.name}/{p.name}' for p in paths_to_archived_models]))
# Out:
# Found archived models:
# ------
# SimpleVAE/archive_v1_2021-04-21
# SimpleAAE/archive_v3_2021-05-07
# BaselineCAE/archive_v1_2021-04-12
# CompressionCAEHighCapacity/archive_v1_2021-04-15
# StandardPCA/archive_v2_2021-04-21
# CompressionCAEMidCapacity/archive_v1_2021-04-15
# CompressionCAEMidCapacity/archive_v2_2021-04-15

# %%
# Load the checkpoints for all the training modules and save them in a dictionary
module_catalog = {}

for pth in paths_to_archived_models:
    
    model_type = pth.parent.name
    model_name = pth.name
    config = tools.load_config(pth / 'configuration.yaml', silent=True)
    
    # Unsupervising region proposal is called implicity in this line, see utils/preprocessing.py
    preprocessing_transforms = supported_preprocessing_transforms[config['data-parameters']['preprocessing']]

    datamodule = supported_datamodules[config['experiment-parameters']['datamodule']](
        data_transforms=preprocessing_transforms,
        **config['data-parameters'])
    
    if 'PCA' in model_type:

        _, pca_test_labels = datamodule.split(train=False)
        
        with open(pth / 'fitted_model.p', 'rb') as f:
            model = pickle.load(f)
            module = PCABaseModule(model)
    else:
        ckpt_path = next(iter((pth / 'checkpoints').glob('val_*')))

        datamodule.setup('test')

        # Handle the various model instantiations
        if 'AAE' in model_type:
            model = supported_models[model_type](
                in_shape=datamodule.data_shape,
                latent_nodes=config['module-parameters']['latent_nodes'])
            module = AAEBaseModule(model, **config['module-parameters'])
        elif 'VAE' in model_type:
            model = supported_models[model_type](
                in_shape=datamodule.data_shape,
                latent_nodes=config['module-parameters']['latent_nodes'])
            module = VAEBaseModule(model, **config['module-parameters'])
        elif 'CAE' in model_type:
            model = supported_models[model_type](in_shape=datamodule.data_shape)
            module = CAEBaseModule(model, **config['module-parameters'])
        else:
            raise ValueError(f'Model substring not found, got {model_type}')

        # Load the state_dict into the module architecture
        checkpoint = torch.load(ckpt_path)
        module.load_state_dict(checkpoint['state_dict'])
    
    if model_type not in module_catalog:
        module_catalog[model_type] = {}
    module_catalog[model_type][model_name] = module
    print(f'Loaded state dict for: {model_type}/{model_name}')
# Out:
# Loaded state dict for: SimpleVAE/archive_v1_2021-04-21
# Loaded state dict for: SimpleAAE/archive_v3_2021-05-07
# Loaded state dict for: BaselineCAE/archive_v1_2021-04-12
# Loaded state dict for: CompressionCAEHighCapacity/archive_v1_2021-04-15
# Loaded state dict for: StandardPCA/archive_v2_2021-04-21
# Loaded state dict for: CompressionCAEMidCapacity/archive_v1_2021-04-15
# Loaded state dict for: CompressionCAEMidCapacity/archive_v2_2021-04-15

# %%
# Collect scores and labels on test set for all models and save to a dictionary
result_catalog = {}

for model_type, model_variants in module_catalog.items():
    start_time = time.time()
    
    for model_name, module in model_variants.items():
        
        test_novelty_scores = []
        test_novelty_labels = []
        short_name = model_type + '-' + model_name.split('_')[1]
        if short_name not in result_catalog:
            result_catalog[short_name] = {
                'scores': [], 
                'labels': []
            }
        print(f'------\n{short_name}\n------')
        
        # Handle the PCA and autoencoder frameworks separately
        if 'PCA' in short_name:
            test_novelty_scores = module.transform_pipeline(datamodule)
            test_novelty_labels = pca_test_labels
        else:
        
            # Set the model/components in evaluation mode
            if 'AAE' in model_type:
                module.encoder.eval()
                module.decoder.eval()
            else:
                module.model.eval()
        
            with torch.no_grad():
                for batch_nb, batch in enumerate(datamodule.test_dataloader()):

                    result = module.test_step(batch, batch_nb)

                    test_novelty_scores.extend(result['scores'])
                    test_novelty_labels.extend(result['labels'].cpu().numpy())
                    print(f'[BATCH {batch_nb}, {len(batch[0])} samples] Mean score: {np.mean(result["scores"])}')
                    
        result_catalog[short_name]['scores'] = test_novelty_scores
        result_catalog[short_name]['labels'] = test_novelty_labels
        print(f'{short_name} Time: {time.time() - start_time:.2f} s\n')
# Out:
# ------
# SimpleVAE-v1
# ------
# [BATCH 0, 1024 samples] Mean score: 0.3446831703186035
# [BATCH 1, 1024 samples] Mean score: 0.34986233711242676
# [BATCH 2, 1024 samples] Mean score: 0.3454062342643738
# [BATCH 3, 1024 samples] Mean score: 0.3507155179977417
# [BATCH 4, 1024 samples] Mean score: 0.34929296374320984
# [BATCH 5, 1024 samples] Mean score: 0.3418767750263214
# [BATCH 6, 1024 samples] Mean score: 0.34939154982566833
# [BATCH 7, 1024 samples] Mean score: 0.34772610664367676
# [BATCH 8, 1024 samples] Mean score: 0.34773415327072144
# [BATCH 9, 784 samples] Mean score: 0.34413909912109375
# SimpleVAE-v1 Time: 3.28 s
#
# ------
# SimpleAAE-v3
# ------
# [BATCH 0, 1024 samples] Mean score: 0.5745812058448792
# [BATCH 1, 1024 samples] Mean score: 0.579025387763977
# [BATCH 2, 1024 samples] Mean score: 0.5741379857063293
# [BATCH 3, 1024 samples] Mean score: 0.576151430606842
# [BATCH 4, 1024 samples] Mean score: 0.5782550573348999
# [BATCH 5, 1024 samples] Mean score: 0.5794404149055481
# [BATCH 6, 1024 samples] Mean score: 0.5775456428527832
# [BATCH 7, 1024 samples] Mean score: 0.5788815021514893
# [BATCH 8, 1024 samples] Mean score: 0.5770773887634277
# [BATCH 9, 784 samples] Mean score: 0.5749516487121582
# SimpleAAE-v3 Time: 1.11 s
#
# ------
# BaselineCAE-v1
# ------
# [BATCH 0, 1024 samples] Mean score: 0.2508472204208374
# [BATCH 1, 1024 samples] Mean score: 0.2540508508682251
# [BATCH 2, 1024 samples] Mean score: 0.2508455216884613
# [BATCH 3, 1024 samples] Mean score: 0.2571044862270355
# [BATCH 4, 1024 samples] Mean score: 0.25141704082489014
# [BATCH 5, 1024 samples] Mean score: 0.24534526467323303
# [BATCH 6, 1024 samples] Mean score: 0.253703236579895
# [BATCH 7, 1024 samples] Mean score: 0.2512032985687256
# [BATCH 8, 1024 samples] Mean score: 0.252405047416687
# [BATCH 9, 784 samples] Mean score: 0.24880218505859375
# BaselineCAE-v1 Time: 21.20 s
#
# ------
# CompressionCAEHighCapacity-v1
# ------
# [BATCH 0, 1024 samples] Mean score: 0.28553104400634766
# [BATCH 1, 1024 samples] Mean score: 0.2883744239807129
# [BATCH 2, 1024 samples] Mean score: 0.2840903401374817
# [BATCH 3, 1024 samples] Mean score: 0.29078802466392517
# [BATCH 4, 1024 samples] Mean score: 0.28748732805252075
# [BATCH 5, 1024 samples] Mean score: 0.280193030834198
# [BATCH 6, 1024 samples] Mean score: 0.2875427007675171
# [BATCH 7, 1024 samples] Mean score: 0.2873488664627075
# [BATCH 8, 1024 samples] Mean score: 0.28773510456085205
# [BATCH 9, 784 samples] Mean score: 0.2830912470817566
# CompressionCAEHighCapacity-v1 Time: 117.71 s
#
# ------
# StandardPCA-v2
# ------
# StandardPCA-v2 Time: 0.76 s
#
# ------
# CompressionCAEMidCapacity-v1
# ------
# [BATCH 0, 1024 samples] Mean score: 0.2949707508087158
# [BATCH 1, 1024 samples] Mean score: 0.29989588260650635
# [BATCH 2, 1024 samples] Mean score: 0.29538464546203613
# [BATCH 3, 1024 samples] Mean score: 0.30158478021621704
# [BATCH 4, 1024 samples] Mean score: 0.29861265420913696
# [BATCH 5, 1024 samples] Mean score: 0.2911257743835449
# [BATCH 6, 1024 samples] Mean score: 0.2976878881454468
# [BATCH 7, 1024 samples] Mean score: 0.2975372076034546
# [BATCH 8, 1024 samples] Mean score: 0.29737433791160583
# [BATCH 9, 784 samples] Mean score: 0.294109582901001
# CompressionCAEMidCapacity-v1 Time: 15.30 s
#
# ------
# CompressionCAEMidCapacity-v2
# ------
# [BATCH 0, 1024 samples] Mean score: 0.3066362738609314
# [BATCH 1, 1024 samples] Mean score: 0.31297165155410767
# [BATCH 2, 1024 samples] Mean score: 0.306983083486557
# [BATCH 3, 1024 samples] Mean score: 0.3137398958206177
# [BATCH 4, 1024 samples] Mean score: 0.311048686504364
# [BATCH 5, 1024 samples] Mean score: 0.30395084619522095
# [BATCH 6, 1024 samples] Mean score: 0.3107454180717468
# [BATCH 7, 1024 samples] Mean score: 0.31133660674095154
# [BATCH 8, 1024 samples] Mean score: 0.3100137412548065
# [BATCH 9, 784 samples] Mean score: 0.30526572465896606
# CompressionCAEMidCapacity-v2 Time: 31.33 s

# %%
# Use standard custom styling
plt.style.use('../../utils/_extras/primary.mplstyle')

# Plot the ROC curves with AUCs for each model
fig, ax = plt.subplots(figsize=(8, 8))
for sn, results in result_catalog.items():

    scores = results['scores']
    labels = results['labels']
    print(f'{sn}: {sum(scores)}')
    
    fpr, tpr, thresholds, auc = metrics.roc(scores, labels)
    
    ax.plot(fpr, tpr, label=f'{sn}: {auc:.2f}')
    
ax.set_xlabel('FPR')
ax.set_ylabel('TPR')
ax.plot([0., 1.], [0., 1.], 'k:', lw=2, label='Random: 0.5')
ax.legend(title='AUC', bbox_to_anchor=(1.05, 1.), loc='upper left')

ax.axhline(0, 0, c='k', lw=1)
ax.axvline(0, 0, c='k', lw=1)

plt.savefig('ROC-all_NoveltyMNIST.pdf', format='pdf', bbox_inches='tight')
plt.show()
print('Random ROC AUC: 0.5')
# Out:
# SimpleVAE-v1: 3471.53369140625
# SimpleAAE-v3: 5770.53466796875
# BaselineCAE-v1: 2516.391357421875
# CompressionCAEHighCapacity-v1: 2862.93408203125
# StandardPCA-v2: 1.6779717100269127e-22
# CompressionCAEMidCapacity-v1: 2968.94384765625
# CompressionCAEMidCapacity-v2: 3093.654296875
# 2021-07-30 17:34:51,217 - WARNING - findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# 2021-07-30 17:34:51,223 - WARNING - findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# 2021-07-30 17:34:51,709 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:51,710 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:51,711 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:51,711 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:51,711 - DEBUG - STREAM b'IDAT' 149 96
# 2021-07-30 17:34:51,713 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:51,714 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:51,714 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:51,715 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:51,715 - DEBUG - STREAM b'IDAT' 149 129
# 2021-07-30 17:34:51,717 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:51,717 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:51,718 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:51,719 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:51,719 - DEBUG - STREAM b'IDAT' 149 124
# 2021-07-30 17:34:51,721 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:51,722 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:51,722 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:51,723 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:51,723 - DEBUG - STREAM b'IDAT' 149 127
# 2021-07-30 17:34:51,725 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:51,726 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:51,726 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:51,726 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:51,727 - DEBUG - STREAM b'IDAT' 149 128
# 2021-07-30 17:34:51,728 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:51,729 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:51,729 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:51,730 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:51,730 - DEBUG - STREAM b'IDAT' 149 97
# 2021-07-30 17:34:51,733 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:51,738 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:51,739 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:51,739 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:51,740 - DEBUG - STREAM b'IDAT' 149 229
# 2021-07-30 17:34:51,753 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:51,754 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:51,756 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:51,756 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:51,757 - DEBUG - STREAM b'IDAT' 149 218
# 2021-07-30 17:34:51,788 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:51,788 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:51,789 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:51,789 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:51,790 - DEBUG - STREAM b'IDAT' 149 226
# 2021-07-30 17:34:51,795 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:51,795 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:51,796 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:51,796 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:51,796 - DEBUG - STREAM b'IDAT' 149 629
# 2021-07-30 17:34:51,799 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:51,799 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:51,800 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:51,800 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:51,801 - DEBUG - STREAM b'IDAT' 149 627
# 2021-07-30 17:34:51,803 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:51,804 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:51,804 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:51,804 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:51,805 - DEBUG - STREAM b'IDAT' 149 609
# 2021-07-30 17:34:51,808 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:51,808 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:51,809 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:51,809 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:51,809 - DEBUG - STREAM b'IDAT' 149 1152
# 2021-07-30 17:34:51,813 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:51,813 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:51,814 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:51,814 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:51,814 - DEBUG - STREAM b'IDAT' 149 666
# 2021-07-30 17:34:51,817 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:51,817 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:51,818 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:51,818 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:51,819 - DEBUG - STREAM b'IDAT' 149 1127
# 2021-07-30 17:34:51,822 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:51,822 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:51,823 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:51,823 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:51,824 - DEBUG - STREAM b'IDAT' 149 1138
# 2021-07-30 17:34:51,827 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:51,828 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:51,828 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:51,829 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:51,829 - DEBUG - STREAM b'IDAT' 149 396
# Random ROC AUC: 0.5

# %% [markdown]
# By evaluating the Precision(k) across all test samples, we make the assumption that all the samples are of the positive class. Clearly this iss an erroneous assumption; conceptually, we should evaluate the Precision(k) only for the novel samples. But this sort of evaluation places a bias on the use of Precision(k) to measure the performance of our detector. By the definition of a novelty, is *cannot* be known beforehand their exact number or frequency. Therefore by analyzing Precision(k) only for the samples we know are novel, because we have insider information about the test data (e.g. labels), we are only evaluating misclassifications of the positive class. Knowing the proportion of correct novelty predictions to total novelty predictions (precision) is important, but it omits a crucial aspect of the usefullness of a detector. Namely, how many *more* false positives would 'flood the results' if typical images were included in the analysis---which they *would* be in an operational scenario.

# %%
# Plot the Precision(k) across all test images.
fig, ax = plt.subplots(figsize=(8, 8))
for sn, results in result_catalog.items():
    
    scores = results['scores']
    labels = results['labels']
    pak = metrics.precision_at_k(scores, labels)

    uniques, counts = np.unique(labels, return_counts=True)
    random = counts.min() / counts.sum()
    pat15 = int(0.15 * counts.sum())

    ax.plot(pak, label=f'{sn}: {pak[int(sum(labels))]:.2f} / {pak[pat15]:.2f}')
    
ax.plot([0, len(pak)], [random, random], 'k:', lw=2, label='$k_{\mathrm{novel}}/k_{\mathrm{total}}$')

ax.set_xlabel('$k$')
ax.set_ylabel('Precision($k$)')
ax.legend(title='Precision($k_{\mathrm{novel}}$) / Precision(15\%)', bbox_to_anchor=(1.05, 1.), loc='upper left')

ax.set_xticks([pat15, counts[1], int(counts.sum()/2), counts.sum()])
ax.set_xticklabels(['15\%', '$k_{\mathrm{novel}}$', int(counts.sum()/2), counts.sum()])

# Draw axes for styling
ax.axhline(0, 0, c='k', lw=0.5)
ax.axvline(0, 0, c='k', lw=0.5)

plt.savefig('Pak-all_NoveltyMNIST.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# 2021-07-30 17:34:53,902 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:53,902 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:53,903 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:53,903 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:53,903 - DEBUG - STREAM b'IDAT' 149 160
# 2021-07-30 17:34:53,906 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:53,906 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:53,907 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:53,907 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:53,907 - DEBUG - STREAM b'IDAT' 149 181
# 2021-07-30 17:34:53,910 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:53,910 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:53,911 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:53,911 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:53,911 - DEBUG - STREAM b'IDAT' 149 129
# 2021-07-30 17:34:53,914 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:53,915 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:53,915 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:53,916 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:53,917 - DEBUG - STREAM b'IDAT' 149 114
# 2021-07-30 17:34:53,920 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:53,920 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:53,920 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:53,921 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:53,921 - DEBUG - STREAM b'IDAT' 149 109
# 2021-07-30 17:34:53,936 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:53,936 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:53,937 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:53,937 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:53,937 - DEBUG - STREAM b'IDAT' 149 687
# 2021-07-30 17:34:53,974 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:53,975 - DEBUG - STREAM b'PLTE' 41 51
# 2021-07-30 17:34:53,975 - DEBUG - STREAM b'tRNS' 104 16
# 2021-07-30 17:34:53,976 - DEBUG - STREAM b'pHYs' 132 9
# 2021-07-30 17:34:53,976 - DEBUG - STREAM b'IDAT' 153 1184
# 2021-07-30 17:34:53,983 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:53,984 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:53,984 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:53,984 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:53,985 - DEBUG - STREAM b'IDAT' 149 779
# 2021-07-30 17:34:53,988 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:53,988 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:53,988 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:53,989 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:53,989 - DEBUG - STREAM b'IDAT' 149 803
# 2021-07-30 17:34:53,992 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:53,993 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:53,993 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:53,993 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:53,994 - DEBUG - STREAM b'IDAT' 149 789
# 2021-07-30 17:34:53,997 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:53,997 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:53,998 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:53,998 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:53,999 - DEBUG - STREAM b'IDAT' 149 1308
# 2021-07-30 17:34:54,003 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:54,004 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:54,005 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:54,005 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:54,006 - DEBUG - STREAM b'IDAT' 149 848
# 2021-07-30 17:34:54,010 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:54,010 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:54,011 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:54,011 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:54,011 - DEBUG - STREAM b'IDAT' 149 1190
# 2021-07-30 17:34:54,016 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:54,016 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:54,017 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:54,017 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:54,017 - DEBUG - STREAM b'IDAT' 149 1237
# 2021-07-30 17:34:54,021 - DEBUG - STREAM b'IHDR' 16 13
# 2021-07-30 17:34:54,022 - DEBUG - STREAM b'PLTE' 41 48
# 2021-07-30 17:34:54,022 - DEBUG - STREAM b'tRNS' 101 15
# 2021-07-30 17:34:54,022 - DEBUG - STREAM b'pHYs' 128 9
# 2021-07-30 17:34:54,023 - DEBUG - STREAM b'IDAT' 149 332

# %% [markdown]
# With the `result_catalog` everything that is needed to analyze and graph results from the archived models trained on Novelty MNIST are available and can be added below. New models that are created according to the system used above can be easily integrated into this experiment and tested in further steps.
